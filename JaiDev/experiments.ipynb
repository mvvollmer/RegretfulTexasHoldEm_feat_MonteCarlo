# %%
from DETERMINISTICAGENTS import AggressiveAgent, RandomAgent, DeterminedAgent, FoldAgent
from QLEARNINGAGENT import QLearningAgent
from REBELAGENT import REBELAgent
from CFRAGENT import CFRAgent
from MCTSAGENT import MCTSAgent
from MCTSCFRAGENT import MCTSCFRAgent
from MCCFRAGENT import MCCFRAgent
from CREATEENVIORMENT import createEnviorment
from LEARNINGLOOP import learningLoop
from PLOTTING import plot_cumulative_winnings

# %%
# implement experiment 
def experiment():
  
  # create agents
  agents = [QLearningAgent(), QLearningAgent(), QLearningAgent(), QLearningAgent(), QLearningAgent(), CFRAgent()]
  player_names = {0: 'QLearningAgent', 1: 'QLearningAgent', 2: 'QLearningAgent', 3: 'QLearningAgent', 4: 'QLearningAgent', 5: 'CFRAgent'}
  active_players = len(agents)
  n_trials = 1
  n_iterations = 1000
  
  track_single_player = False
  # Bounds for randomizing player stack sizes in reset()
  low_stack_bbs = 499
  high_stack_bbs = 500
  hand_history_location = 'JaiHands/'
  invalid_action_penalty = 10
  
  total_winnings = []
  for t in range(n_trials):
    # create enviorment
    env = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)

    # run learning loop
    results = learningLoop(env, agents, active_players, n_iterations)
      
    # plot results
    total_winnings.append(results)

  player_names_list = [player_names[i] for i in range(active_players)] 
  plot_cumulative_winnings(total_winnings, player_names_list, n_iterations)
    
experiment()
# Out:
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000

# %%
# implement experiment 
def experiment():
  
  # create agents
  agents = [AggressiveAgent(), RandomAgent(), DeterminedAgent(), FoldAgent(), QLearningAgent(), CFRAgent()]
  player_names = {0: 'AggressiveAgent', 1: 'RandomAgent', 2: 'DeterminedAgent', 3: 'FoldAgent', 4: 'QLearningAgent', 5: 'CFRAgent'}
  active_players = len(agents)
  n_trials = 1
  n_iterations = 1000
  
  track_single_player = False
  # Bounds for randomizing player stack sizes in reset()
  low_stack_bbs = 499
  high_stack_bbs = 500
  hand_history_location = 'JaiHands/'
  invalid_action_penalty = 10
  
  total_winnings = []
  for t in range(n_trials):
    # create enviorment
    env = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)

    # run learning loop
    results = learningLoop(env, agents, active_players, n_iterations)
      
    # plot results
    total_winnings.append(results)

  player_names_list = [player_names[i] for i in range(active_players)] 
  plot_cumulative_winnings(total_winnings, player_names_list, n_iterations)
    
experiment()
# Out:
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000

# %%
# implement experiment 
def experiment():
  
  # create agents
  agents = [QLearningAgent(), QLearningAgent(), QLearningAgent(), QLearningAgent(), QLearningAgent(), MCTSAgent()]
  player_names = {0: 'QLearningAgent', 1: 'QLearningAgent', 2: 'QLearningAgent', 3: 'QLearningAgent', 4: 'QLearningAgent', 5: 'MCTSAgent'}
  active_players = len(agents)
  n_trials = 1
  n_iterations = 1000
  
  track_single_player = False
  # Bounds for randomizing player stack sizes in reset()
  low_stack_bbs = 499
  high_stack_bbs = 500
  hand_history_location = 'JaiHands/'
  invalid_action_penalty = 10
  
  total_winnings = []
  for t in range(n_trials):
    # create enviorment
    env = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)

    # run learning loop
    results = learningLoop(env, agents, active_players, n_iterations)
      
    # plot results
    total_winnings.append(results)

  player_names_list = [player_names[i] for i in range(active_players)] 
  plot_cumulative_winnings(total_winnings, player_names_list, n_iterations)
    
experiment()
# Out:
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000

# %%
# implement experiment 
def experiment():
  
  # create agents
  agents = [AggressiveAgent(), RandomAgent(), DeterminedAgent(), FoldAgent(), QLearningAgent(), MCTSAgent()]
  player_names = {0: 'AggressiveAgent', 1: 'RandomAgent', 2: 'DeterminedAgent', 3: 'FoldAgent', 4: 'QLearningAgent', 5: 'MCTSAgent'}
  active_players = len(agents)
  n_trials = 1
  n_iterations = 1000
  
  track_single_player = False
  # Bounds for randomizing player stack sizes in reset()
  low_stack_bbs = 499
  high_stack_bbs = 500
  hand_history_location = 'JaiHands/'
  invalid_action_penalty = 10
  
  total_winnings = []
  
  for t in range(n_trials):
    print("Trial: ", t)
    
    # create enviorment
    env = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)

    # run learning loop
    results = learningLoop(env, agents, active_players, n_iterations)
      
    # plot results
    total_winnings.append(results)

  player_names_list = [player_names[i] for i in range(active_players)] 
  plot_cumulative_winnings(total_winnings, player_names_list, n_iterations)
    
experiment()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 32
#      29   player_names_list = [player_names[i] for i in range(active_players)]
#      30   plot_cumulative_winnings(total_winnings, player_names_list, n_iterations)
# ---> 32 experiment()
#
# Cell In[30], line 24, in experiment()
#      21 env = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)
#      23 # run learning loop
# ---> 24 results = learningLoop(env, agents, active_players, n_iterations)
#      26 # plot results
#      27 total_winnings.append(results)
#
# File ~/Documents/College/Fall 2024/rl/RegretfulTexasHoldEm_feat_MonteCarlo/JaiDev/LEARNINGLOOP.py:70, in learningLoop(table, agents, active_players, n_iterations, batch_size, train_interval)
#      68     action = agent.get_action(state)
# ...

# %%
# implement experiment 
def experiment():
  
  # create agents
  agents = [QLearningAgent(), QLearningAgent(), QLearningAgent(), QLearningAgent(), QLearningAgent(), MCCFRAgent()]
  player_names = {0: 'QLearningAgent', 1: 'QLearningAgent', 2: 'QLearningAgent', 3: 'QLearningAgent', 4: 'QLearningAgent', 5: 'MCCFRAgent'}
  active_players = len(agents)
  n_trials = 10
  n_iterations = 1000
  
  track_single_player = False
  # Bounds for randomizing player stack sizes in reset()
  low_stack_bbs = 499
  high_stack_bbs = 500
  hand_history_location = 'JaiHands/'
  invalid_action_penalty = 10
  
  total_winnings = []
  for t in range(n_trials):
    # create enviorment
    env = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)

    # run learning loop
    results = learningLoop(env, agents, active_players, n_iterations)
      
    # plot results
    total_winnings.append(results)

  player_names_list = [player_names[i] for i in range(active_players)] 
  plot_cumulative_winnings(total_winnings, player_names_list, n_iterations)
    
experiment()
# Out:
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# ...

# %%
# implement experiment 
def experiment():
  
  # create agents
  agents = [AggressiveAgent(), RandomAgent(), DeterminedAgent(), FoldAgent(), QLearningAgent(), MCCFRAgent()]
  player_names = {0: 'AggressiveAgent', 1: 'RandomAgent', 2: 'DeterminedAgent', 3: 'FoldAgent', 4: 'QLearningAgent', 5: 'MCCFRAgent'}
  active_players = len(agents)
  n_trials = 10
  n_iterations = 1000
  
  track_single_player = False
  # Bounds for randomizing player stack sizes in reset()
  low_stack_bbs = 499
  high_stack_bbs = 500
  hand_history_location = 'MilesHands/'
  invalid_action_penalty = 10
  
  total_winnings = []
  for t in range(n_trials):
    # create enviorment
    env = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)

    # run learning loop
    results = learningLoop(env, agents, active_players, n_iterations)
      
    # plot results
    total_winnings.append(results)

  player_names_list = [player_names[i] for i in range(active_players)] 
  plot_cumulative_winnings(total_winnings, player_names_list, n_iterations)
    
experiment()
# Out:
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# ...
