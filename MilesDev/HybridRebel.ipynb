# %% [markdown]
# # HybridRebel Run

# %%
from DETERMINISTICAGENTS import AggressiveAgent, RandomAgent, DeterminedAgent, FoldAgent
from QLEARNINGAGENT import QLearningAgent
from REBELAGENT import REBELAgent
from CREATEENVIORMENT import createEnviorment
from LEARNINGLOOP import learningLoop
from PLOTTING import plot_cumulative_winnings
from HybridPokerAgent import HybridPokerAgent

# %%
active_players = 6
agents = [QLearningAgent(), HybridPokerAgent(num_players=6), AggressiveAgent(), RandomAgent(), DeterminedAgent(), FoldAgent()]
player_names = {0: 'QLearning', 1: 'HybRebel', 2: 'Aggressive', 3:'Random',4:'Determined',5:'Fold'} # Rest are defaulted to player3, player4...
# Should we only log the 0th players (here TrackedAgent1) private cards to hand history files
track_single_player = False
# Bounds for randomizing player stack sizes in reset()
low_stack_bbs = 500
high_stack_bbs = 501
hand_history_location = 'MilesHands/'
invalid_action_penalty = 10

# %%
n_trials = 10
n_iterations = 1000
total_winnings = []
for t in range(n_trials):
    table = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)
    table.seed(t)
    player_winnings = learningLoop(table, agents, active_players, n_iterations)
    print(f"Trial {t+1} completed")
    total_winnings.append(player_winnings)
# Out:
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 1 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 2 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 3 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 4 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 5 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 6 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 7 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 8 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 9 completed
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# Iteration: 300
# Iteration: 350
# Iteration: 400
# Iteration: 450
# Iteration: 500
# Iteration: 550
# Iteration: 600
# Iteration: 650
# Iteration: 700
# Iteration: 750
# Iteration: 800
# Iteration: 850
# Iteration: 900
# Iteration: 950
# Iteration: 1000
# Trial 10 completed

# %%
RVQVDETRM = plot_cumulative_winnings(total_winnings, ["Q Agent 1", "CFR + Rebel Agent", "Aggressive Agent", "Random Agent", "Determined Agent", "Fold Agent"], n_iterations)
