# %% [markdown]
# # Rebel vs Q-Learning vs Random vs Deterministic Agents

# %% [markdown]
# ## Imports

# %%
from DETERMINISTICAGENTS import AggressiveAgent, RandomAgent, DeterminedAgent, FoldAgent
from QLEARNINGAGENT import QLearningAgent
from REBELAGENT import REBELAgent
from CREATEENVIORMENT import createEnviorment
from LEARNINGLOOP import learningLoop
from PLOTTING import plot_cumulative_winnings

# %% [markdown]
# ## Setup

# %%
active_players = 6
agents = [QLearningAgent(), REBELAgent(num_players=6), AggressiveAgent(), RandomAgent(), DeterminedAgent(), FoldAgent()]
player_names = {0: 'QLearning', 1: 'Rebel', 2: 'Aggressive', 3:'Random',4:'Determined',5:'Fold'} # Rest are defaulted to player3, player4...
# Should we only log the 0th players (here TrackedAgent1) private cards to hand history files
track_single_player = False
# Bounds for randomizing player stack sizes in reset()
low_stack_bbs = 300
high_stack_bbs = 301
hand_history_location = 'MilesHands/'
invalid_action_penalty = 10

# %% [markdown]
# ## Run Through

# %%
n_trials = 1
n_iterations = 1000
total_winnings = []
for t in range(n_trials):
    table = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)
    table.seed(t)
    player_winnings = learningLoop(table, agents, active_players, n_iterations)
    print(f"Trial {t+1} completed")
    total_winnings.append(player_winnings)
# Out:
# Iteration: 50
# Iteration: 100
# Iteration: 150
# Iteration: 200
# Iteration: 250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 table = createEnviorment(active_players, agents, player_names, low_stack_bbs, high_stack_bbs, hand_history_location, invalid_action_penalty, track_single_player)
#       6 table.seed(t)
# ----> 7 player_winnings = learningLoop(table, agents, active_players, n_iterations)
#       8 print(f"Trial {t+1} completed")
#       9 total_winnings.append(player_winnings)
#
# File ~/Desktop/MilesDev/LEARNINGLOOP.py:67, in learningLoop(table, agents, active_players, n_iterations, batch_size, train_interval)
#      65 # Fetch action from the agent
#      66 if isinstance(agent, REBELAgent):
# ---> 67     state = featurize_state(playerCards, communityCards, playerBets)
#      68     action = agent.get_action(state)
#      69 else:
#
# File ~/Desktop/MilesDev/FEATURIZESTATE.py:55, in featurize_state(player_hand, community_cards, opponent_bets)
#      45 """
#      46 Combine hand and opponent metrics into a single state vector.
#      47 Args:
#    (...)
#      52     np.array: Full state vector.
#      53 """
#      54 hand_features = HandEvaluator.featurize_hand(player_hand, community_cards)
# ---> 55 opponent_features = featurize_opponents(opponent_bets)
#      56 return np.concatenate([hand_features, opponent_features])
#
# File ~/Desktop/MilesDev/FEATURIZESTATE.py:21, in featurize_opponents(opponent_bets)
#      19 # Basic statistics
#      20 features.append(np.min(bets_array))
# ---> 21 features.append(np.median(bets_array))
#      22 features.append(mean_bet)
#      23 features.append(np.max(bets_array))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/function_base.py:3927, in median(a, axis, out, overwrite_input, keepdims)
#    3845 @array_function_dispatch(_median_dispatcher)
#    3846 def median(a, axis=None, out=None, overwrite_input=False, keepdims=False):
#    3847     """
#    3848     Compute the median along the specified axis.
#    3849
#    (...)
#    3925
#    3926     """
# -> 3927     return _ureduce(a, func=_median, keepdims=keepdims, axis=axis, out=out,
#    3928                     overwrite_input=overwrite_input)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/function_base.py:3960, in _median(a, axis, out, overwrite_input)
#    3958         part = a
#    3959 else:
# -> 3960     part = partition(a, kth, axis=axis)
#    3962 if part.shape == ():
#    3963     # make 0-D arrays work
#    3964     return part.item()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:771, in partition(a, kth, axis, kind, order)
#     769 else:
#     770     a = asanyarray(a).copy(order="K")
# --> 771 a.partition(kth, axis=axis, kind=kind, order=order)
#     772 return a
#
# KeyboardInterrupt:

# %%
print(total_winnings)
# Out:
